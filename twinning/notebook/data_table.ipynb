# %% [markdown]
# # predicting tyming of data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive/MyDrive/'Colab Notebooks'/eecs545/twinning

# %%
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
X = pd.read_csv("../data/transient_pred/scalar_res.csv")

# %%
X.iloc[:, 0:6].describe()

# %%
valiables = ["h1_log",
             "h2_log",
             "Eturb_log",
             "omega_log",
             "P1_log",
             "P2_log",
            "Pout_log",
             "rho1_log",
             "rho2_log",
             "T1_log",
             "T2_log",
             "Tboil_log",
             "x1_log",
             "x2_log"
             ]

# %%
for val in valiables:
    path = "../data/transient_pred/" +  val + ".csv"
    pred_Data = pd.read_csv(path)
    print(val)
    print(pred_Data.mean().mean())
    print(np.nanstd(pred_Data.values))
    print(np.nanmin(pred_Data.values))
    print(np.nanmax(pred_Data.values))
